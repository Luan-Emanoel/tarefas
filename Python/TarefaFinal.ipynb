# %%
import networkx as net
G= net.Graph()

texto = "Teste"
tamanho = 2
lista = []
for i in range (len (texto)):
  if len(texto [i:i+tamanho]) == k:
    lista.append (texto[i:i+tamanho])

G.add_nodes_from(lista)



for x in range(len(lista) -1, -1 , -1):
  G.add_edge(lista[x], lista[x-1])

euleriano = net.is_eulerian(G)

if euleriano == True:
  print("O grafo é euleriano")
else:
  print("O grafo não é euleriano")

net.draw(G,with_labels = True)


for y in range(len(lista)):
  print(lista[y], end = '')
# Out:
# O grafo é euleriano
# Teesstte
